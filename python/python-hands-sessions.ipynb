# %%
x + 6
# Out:
# 9

# %%
2 + 3 # Press shift+enter
# Out:
# 5

# %%
x = 3

# %%
x = 5
if x < 10:
    print("Smaller'\\\"")
if x > 20:
     print('Bigger')

print('Finis"\'')
# Out:
# Smaller'\"
# Finis"'

# %%
n = 5
while n > 0:
    print(n)
    n = n - 1
print('Blastoff!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!

# %%
name = input('Enter file:')
handle = open(name, 'r')
text = handle.read()
words = text.split()
counts = dict()
for word in words:
   counts[word] = counts.get(word,0) + 1

bigcount = None
bigword = None
for word,count in counts.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

print(bigword, bigcount)
# Out:
# Enter file:big.txt
# the 71744

# %%
counts.get('theXXX', 0)
# Out:
# 0

# %%
counts.get('the', 0)
# Out:
# 71744

# %%
counts['the']
# Out:
# 71744

# %%
4 % 2
# Out:
# 0

# %%
5 % 6
# Out:
# 5

# %%
x = 11
x % 2 != 0
# Out:
# True

# %%
x = True

# %%
3 / 4
# Out:
# 0.75

# %%
3 // 2
# Out:
# 1

# %%
2 + 3
# Out:
# 5

# %%
"2" + "3"
# Out:
# '23'

# %%
"2" + str(3)
# Out:
# '23'

# %%
int("2") + 3
# Out:
# 5

# %%
float("3.4")
# Out:
# 3.4

# %%
name = input("Whats your name? ")
# Out:
# Whats your name? Sandeep

# %%
name
# Out:
# 'Sandeep'

# %%
name?

# %%
input?

# %%
name
# Out:
# 'Sandeep'

# %%
name.upper()
# Out:
# 'SANDEEP'

# %%
counts.get?

# %%
help(counts.get)
# Out:
# Help on built-in function get:
#
# get(...) method of builtins.dict instance
#     D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.

# %%
'a'*3
# Out:
# 'aaa'

# %% [markdown]
# ## Rectangle
# x1, y1, x2, y2
#
# ## point
# px, py
#
# ### Write a code to print "Yes" if the point exists inside rectangle else print "No"

# %%
astr = 'Hello Bob'
istr = int(astr)
istr = -1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-ee708147b8c9> in <module>()
#       1 astr = 'Hello Bob'
# ----> 2 istr = int(astr)
#       3 istr = -1
#
# ValueError: invalid literal for int() with base 10: 'Hello Bob'

# %%
astr = 'Hello Bob'
try:
    istr = int(astr)
except:
    istr = -1

# %%
istr
# Out:
# -1

# %%
astr = '234'
try:
    istr = int(astr)
except:
    istr = -1

# %%
istr
# Out:
# 234

# %%
x = 3

# %%
x
# Out:
# 3

# %%
x == 3
# Out:
# True

# %%
if x <= 3 or x >= 2:
    print("Yes")
else:
    print("no")
# Out:
# Yes

# %%
def f(name):
    print("hello")
    print("world")
    print(name)

# %%
f("sandeep")
# Out:
# hello
# world
# sandeep

# %%
import math

def dist(x1, y1, x2, y2):
    d = math.sqrt(sq2(x1 - x2) + sq2(y1 - y2))
    print(d)

def sq2(x):
    return x*x

dist(1, 1,1,1)
# Out:
# 0.0

# %%
sq(3)
# Out:
# 9

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
dist(0,0, 1, 1)
# Out:
# 1.4142135623730951

# %%
def orderi(x, y):
    if x > y:
        return (x, y)
    return (y, x)

# %%
(x1, y1) = orderi(3,40)

# %%
x1
# Out:
# 40

# %%
y1
# Out:
# 3

# %%
max("sandeep")
# Out:
# 's'

# %%
def f(x):
  x = 5
  return x

# %%
y = 6
f(y)
print(y)
# Out:
# 6

# %%
f
# Out:
# <function __main__.f>

# %%
n = 2
while n > 0 :
    print (n)
    n = n - 1
print ('Blastoff!')
print (n)
# Out:
# 2
# 1
# Blastoff!
# 0

# %%
# CTRL + D -> End of Input
# CTRL + C -> Sends kill singal to the proces

# %%
# fact(n) = n*n-1*n-2.....3*2*1

n = 4
fact = 1
while True :
    fact = fact * n
    n = n - 1
    if n < 1:
        break
print (fact)
# Out:
# 24

# %%
def factr(n):
    if n < 2:
        return 1
    else:
        return n*factr(n-1)

# %%
factr(1)
# Out:
# 1

# %%
factr(2)
# Out:
# 2

# %%
factr(3)
# Out:
# 6

# %%
factr(0)
# Out:
# 1

# %%
while True:
    line = input("> ")
    if line[0] == '#' :
        continue
    if line == 'done' :
        break
    print (line)
print ('Done!')
# Out:
# > #ddd
# > done
# Done!

# %%
line = input("Enter: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2344)()
#
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-c4d676dd18a8> in <module>()
# ----> 1 line = input("Enter: ")
#
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
line = input("Enter:")
# Out:
# Enter:s

# %%
range?

# %%
for i in range(5) :
    print (i)
print ('Blastoff!')
# Out:
# 0
# 1
# 2
# 3
# 4
# Blastoff!

# %%
x = [3,4,4,"4"]

# %%
print(x)
# Out:
# [3, 4, 4, '4']

# %%
largest_so_far = -1
print ('Before', largest_so_far)
for the_num in [9, 41, 12, 3, 74, 15] :
   if the_num > largest_so_far :
      largest_so_far = the_num
   print (largest_so_far, the_num)

print ('After', largest_so_far)
# Out:
# Before -1
# 9 9
# 41 41
# 41 12
# 41 3
# 74 74
# 74 15
# After 74

# %%
x = None

# %%
smallest = None
print ('Before')
for value in [3, 41, 12, 9, 74, 15] :
    if smallest is None : 
        smallest = value
    elif value < smallest : 
        smallest = value
    print (smallest, value)
print ('After', smallest)
# Out:
# Before
# 3 3
# 3 41
# 3 12
# 3 9
# 3 74
# 3 15
# After 3

# %%
ord('a')
# Out:
# 97

# %%
print("y \\ x")
# Out:
# y \ x

# %%
print("this \\\" is how you comment")
# Out:
# this \" is how you comment

# %%
print('this \\" is how you comment')
# Out:
# this \" is how you comment

# %%
fruit = 'banana'

# %%
fruit[1]
# Out:
# 'a'

# %%
for i in fruit:
    print(i)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruit[1:3]
# Out:
# 'an'

# %%
len(fruit)
# Out:
# 6

# %%
fruit
# Out:
# 'banana'

# %%
if 'ban' in 'banana':
    print("ye!")
else:
    print("OOps")
# Out:
# ye!

# %%
"apples" < "oranges"
# Out:
# True

# %%
ord("a")
# Out:
# 97

# %%
ord("o")
# Out:
# 111

# %%
greet = 'Hello Bob'
nstr = greet.replace('Bob','Jane')
print (nstr)
# Out:
# Hello Jane

# %%
print(greet)
# Out:
# Hello Bob

# %%
data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
atpos = data.find('@')
print (atpos)
# Out:
# 21

# %%
data[atpos:]
# Out:
# '@uct.ac.za Sat Jan  5 09:14:16 2008'

# %%
endpos = data.find(' ', atpos)

# %%
data[atpos+1:endpos]
# Out:
# 'uct.ac.za'

# %%
fhand = open('mbox-short.txt', 'r')

# %%
for line in fhand:
    if line.startswith('From:') :
        l = line.rstrip()
        print(l.split()[1])
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu

# %%
print("sandeep\ngiri")
# Out:
# sandeep
# giri

# %%
fhand = open('mbox-short_sg.txt', 'w')

# %%
fhand.write("hey")
fhand.close()

# %%
for lines in open('mbox-short_sg.txt'):
    print(lines)
# Out:
# hihey

# %%
# !cat mbox-short_sg.txt
# Out:
# hey

# %%
friends = [ 'Joseph', 'Glenn', 'Sally' ]

# %%
friends[0]
# Out:
# 'Joseph'

# %%
friends[1:2]
# Out:
# ['Glenn']

# %%
friends[2] = "Shally"

# %%
friends
# Out:
# ['Joseph', 'Glenn', 'Shally']

# %%
s = "sandeep"
s[0] = "S"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-bf244a479297> in <module>()
#       1 s = "sandeep"
# ----> 2 s[0] = "S"
#
# TypeError: 'str' object does not support item assignment

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = []
b = list()

# %%
type(a)
# Out:
# list

# %%
type(b)
# Out:
# list

# %%
a
# Out:
# []

# %%
a.append(1)

# %%
a
# Out:
# [1]

# %%
a.append(2)

# %%
a
# Out:
# [1, 2]

# %%
a.pop()
# Out:
# 2

# %%
a
# Out:
# [1]

# %%
a.remove(1)

# %%
a
# Out:
# []

# %%
friends = [ 'Joseph', 'Glenn', 'Sally' ]
friends.sort()
print (friends)
# Out:
# ['Glenn', 'Joseph', 'Sally']

# %%
purse = dict()
purse['money'] = 12
purse['candy'] = 3
purse['tissues'] = 75
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
a = {'money': 12, 'candy': 3, 'tissues': 75}

# %%
a
# Out:
# {'candy': 3, 'money': 12, 'tissues': 75}

# %%
type(a)
# Out:
# dict

# %%
a['money'] = 20

# %%
a.get('dollars', "No Money")
# Out:
# 'No Money'

# %%
a['dollars'] = 56

# %%
a
# Out:
# {'candy': 3, 'dollars': 56, 'money': 12, 'tissues': 75}

# %%
a.keys()
# Out:
# dict_keys(['money', 'candy', 'tissues', 'dollars'])

# %%
a.values()
# Out:
# dict_values([12, 3, 75, 56])

# %%
max = None
maxkey = None
for it in a.items():
    if max == None or max < it[1]:
        max = it[1]
        maxkey = it[0]
print(maxkey)
# Out:
# tissues

# %%
a
# Out:
# {'candy': 3, 'dollars': 56, 'money': 12, 'tissues': 75}

# %%
"money1" in a
# Out:
# False

# %%
for k, v in a.items():
    print("%s : %5d" % (k, v))
# Out:
# money :    12
# candy :     3
# tissues :    75
# dollars :    56

# %%
x = ('Glenn', 'Sally', 'Joseph')
y = ['Glenn', 'Sally', 'Joseph']

# %%
type(x)
# Out:
# tuple

# %%
type(y)
# Out:
# list

# %%
y[1] = "glenn"

# %%
x
# Out:
# ('Glenn', 'Sally', 'Joseph')

# %%
y
# Out:
# ['Glenn', 'glenn', 'Joseph']

# %%
(0, 1, 2) < (0, 1, 2, 3)
# Out:
# True

# %%
x,y = 2, 3

# %%
x
# Out:
# 2

# %%
type((0, 1, 2))
# Out:
# tuple

# %%
(0, 1, 2) < (0, 1, 2)
# Out:
# False

# %%
(0, 1, 2) < (0, 1, 2, 1)
# Out:
# True

# %%
(0, 1, 2) < (0, 1, 3)
# Out:
# True

# %%
(0, 1, 2) < (0, 0, 0, 1)
# Out:
# False

# %%
(0, 1, 2) < (0, 1, 2, -1)
# Out:
# True

# %%
sorted(a.items())
# Out:
# [('candy', 3), ('dollars', 56), ('money', 12), ('tissues', 75)]

# %%
L = [(0, 1, 2), (0, 1, 2), (0, 1, 2, 1), (0, 1, 3), (0, 0, 0, 1), (0, 1, 2, -1)]
sorted(L)
# Out:
# [(0, 0, 0, 1), (0, 1, 2), (0, 1, 2), (0, 1, 2, -1), (0, 1, 2, 1), (0, 1, 3)]

# %%
 (1,2,3) < (1,2,3, -1)
# Out:
# True

# %%
c = {'a':10, 'b':1, 'c':22}

# %%
c.items()
# Out:
# dict_items([('a', 10), ('b', 1), ('c', 22)])

# %%
sorted( [ (v,k) for k,v in c.items() ], reverse=True)[0]
# Out:
# (22, 'c')

# %%
list =  [ (v,k) for k,v in c.items() ]

# %%
list = []
for k,v in c.items():
    list.append((v, k))

# %%
[(x*x,0) for x in [1,2,3]]
# Out:
# [(1, 0), (4, 0), (9, 0)]
